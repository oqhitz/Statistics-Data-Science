# %% [markdown]
# ***
# HOMEWORK STATISTICS FOR DATA SCIENCE
#
# SHIFT ACADEMY DATA SCIENCE BOOTCAMP BATCH 9
#
# By Prayuda Satya Graha
# ***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %matplotlib inline

# %% [markdown]
# LOADING DATASET

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Dataset Info

# %%
df.info()
print('\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# Dataset Statistical Description

# %%
print(df.describe())
print('\n')
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Dataset Shape

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# Dataset Central Tendencies

# %% [markdown]
# Average / Mean

# %%
print('Sepal length average of all Iris Flowers species: %1.2f cm' % df['SepalLengthCm'].mean())
print('Sepal Width average of all Iris Flowers species: %1.2f cm' % df['SepalWidthCm'].mean())
print('Petal Length average of all Iris Flowers species: %1.2f cm' % df['PetalLengthCm'].mean())
print('Petal Width average of all Iris Flowers species: %1.2f cm' % df['PetalWidthCm'].mean())
# Out:
# Sepal length average of all Iris Flowers species: 5.84 cm
# Sepal Width average of all Iris Flowers species: 3.05 cm
# Petal Length average of all Iris Flowers species: 3.76 cm
# Petal Width average of all Iris Flowers species: 1.20 cm

# %% [markdown]
# Median

# %%
print('Sepal length median of all Iris Flowers species: %1.2f cm' % df['SepalLengthCm'].median())
print('Sepal Width median of all Iris Flowers species: %1.2f cm' % df['SepalWidthCm'].median())
print('Petal Length median of all Iris Flowers species: %1.2f cm' % df['PetalLengthCm'].median())
print('Petal Width median of all Iris Flowers species: %1.2f cm' % df['PetalWidthCm'].median())
# Out:
# Sepal length median of all Iris Flowers species: 5.80 cm
# Sepal Width median of all Iris Flowers species: 3.00 cm
# Petal Length median of all Iris Flowers species: 4.35 cm
# Petal Width median of all Iris Flowers species: 1.30 cm

# %% [markdown]
# Modes

# %%
print('Sepal length mode of all Iris Flowers species: %1.2f cm' % df['SepalLengthCm'].mode())
print('Sepal Width mode of all Iris Flowers species: %1.2f cm' % df['SepalWidthCm'].mode())
print('Petal Length mode of all Iris Flowers species: %1.2f cm' % df['PetalLengthCm'].mode())
print('Petal Width mode of all Iris Flowers species: %1.2f cm' % df['PetalWidthCm'].mode())
# Out:
# Sepal length mode of all Iris Flowers species: 5.00 cm
# Sepal Width mode of all Iris Flowers species: 3.00 cm
# Petal Length mode of all Iris Flowers species: 1.50 cm
# Petal Width mode of all Iris Flowers species: 0.20 cm

# %% [markdown]
# First Quartile

# %%
print('Sepal length 1st Quartile of all Iris Flowers species: %1.2f cm' % df['SepalLengthCm'].quantile(0.25))
print('Sepal Width 1st Quartile of all Iris Flowers species: %1.2f cm' % df['SepalWidthCm'].quantile(0.25))
print('Petal Length 1st Quartile of all Iris Flowers species: %1.2f cm' % df['PetalLengthCm'].quantile(0.25))
print('Petal Width 1st Quartile of all Iris Flowers species: %1.2f cm' % df['PetalWidthCm'].quantile(0.25))
# Out:
# Sepal length 1st Quartile of all Iris Flowers species: 5.10 cm
# Sepal Width 1st Quartile of all Iris Flowers species: 2.80 cm
# Petal Length 1st Quartile of all Iris Flowers species: 1.60 cm
# Petal Width 1st Quartile of all Iris Flowers species: 0.30 cm

# %% [markdown]
# Third Quartile

# %%
print('Sepal length 3rd Quartile of all Iris Flowers species: %1.2f cm' % df['SepalLengthCm'].quantile(0.75))
print('Sepal Width 3rd Quartile of all Iris Flowers species: %1.2f cm' % df['SepalWidthCm'].quantile(0.75))
print('Petal Length 3rd Quartile of all Iris Flowers species: %1.2f cm' % df['PetalLengthCm'].quantile(0.75))
print('Petal Width 3rd Quartile of all Iris Flowers species: %1.2f cm' % df['PetalWidthCm'].quantile(0.75))
# Out:
# Sepal length 3rd Quartile of all Iris Flowers species: 6.40 cm
# Sepal Width 3rd Quartile of all Iris Flowers species: 3.30 cm
# Petal Length 3rd Quartile of all Iris Flowers species: 5.10 cm
# Petal Width 3rd Quartile of all Iris Flowers species: 1.80 cm

# %% [markdown]
# Percentile 90, Percentile 99

# %%
print('Sepal length Percentile(90) of all Iris Flowers species: %1.2f cm' % df['SepalLengthCm'].quantile(0.9))
print('Sepal Width Percentile(90) of all Iris Flowers species: %1.2f cm' % df['SepalWidthCm'].quantile(0.9))
print('Petal Length Percentile(90) of all Iris Flowers species: %1.2f cm' % df['PetalLengthCm'].quantile(0.9))
print('Petal Width Percentile(90) of all Iris Flowers species: %1.2f cm' % df['PetalWidthCm'].quantile(0.9))
print('\n')
print('Sepal length Percentile(99) of all Iris Flowers species: %1.2f cm' % df['SepalLengthCm'].quantile(0.99))
print('Sepal Width Percentile(99) of all Iris Flowers species: %1.2f cm' % df['SepalWidthCm'].quantile(0.99))
print('Petal Length Percentile(99) of all Iris Flowers species: %1.2f cm' % df['PetalLengthCm'].quantile(0.99))
print('Petal Width Percentile(99) of all Iris Flowers species: %1.2f cm' % df['PetalWidthCm'].quantile(0.99))
print('\n')
# Out:
# Sepal length Percentile(90) of all Iris Flowers species: 6.90 cm
# Sepal Width Percentile(90) of all Iris Flowers species: 3.61 cm
# Petal Length Percentile(90) of all Iris Flowers species: 5.80 cm
# Petal Width Percentile(90) of all Iris Flowers species: 2.20 cm
#
#
# Sepal length Percentile(99) of all Iris Flowers species: 7.70 cm
# Sepal Width Percentile(99) of all Iris Flowers species: 4.15 cm
# Petal Length Percentile(99) of all Iris Flowers species: 6.70 cm
# Petal Width Percentile(99) of all Iris Flowers species: 2.50 cm

# %% [markdown]
# Histogram

# %%
sns.histplot(df['SepalLengthCm'])
plt.title('Histogram of Iris Flowers Sepal Length', fontweight='bold')
plt.ylabel('Frequency')
plt.xlabel('Sepal Length (in cm)')
plt.show()

# %%
sns.histplot(df['SepalWidthCm'])
plt.title('Histogram of Iris Flowers Sepal Width', fontweight='bold')
plt.ylabel('Frequency')
plt.xlabel('Sepal Width (in cm)')
plt.show()

# %%
sns.histplot(df['PetalLengthCm'])
plt.title('Histogram of Iris Flowers Petal Length', fontweight='bold')
plt.ylabel('Frequency')
plt.xlabel('Petal Length (in cm)')
plt.show()

# %%
sns.histplot(df['PetalWidthCm'])
plt.title('Histogram of Iris Flowers Petal Width', fontweight='bold')
plt.ylabel('Frequency')
plt.xlabel('Petal Width (in cm)')
plt.show()

# %% [markdown]
# Correlation Coefficient between variables

# %%
numerical_column = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

df[numerical_column].corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df[numerical_column].corr())
plt.show()

# %%
SL = df['SepalLengthCm']
SW = df['SepalWidthCm']
PL = df['PetalLengthCm']
PW = df['PetalWidthCm']

plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(df['SepalLengthCm'], df['SepalWidthCm'], label = f'Sepal Length and Sepal Width Corr = {np.round(np.corrcoef(SL,SW)[0,1], 2)}', marker='.')
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], label = f'Sepal Length and Petal Length Corr = {np.round(np.corrcoef(SL,PL)[0,1], 2)}', marker='.')
plt.scatter(df['SepalLengthCm'], df['PetalWidthCm'], label = f'Sepal Length and Petal Width Corr = {np.round(np.corrcoef(SL,PW)[0,1], 2)}', marker='.')
plt.title('Sepal Length Correlation', fontweight='bold')
plt.xlabel('Sepal Length')
plt.legend(loc = 'best', fontsize = 8)
plt.show()

# %%
plt.scatter(df['SepalWidthCm'], df['SepalLengthCm'], label = f'Sepal Width and Sepal Length Corr = {np.round(np.corrcoef(SW,SL)[0,1], 2)}', marker='.')
plt.scatter(df['SepalWidthCm'], df['PetalLengthCm'], label = f'Sepal Width and Petal Length Corr = {np.round(np.corrcoef(SW,PL)[0,1], 2)}', marker='.')
plt.scatter(df['SepalWidthCm'], df['PetalWidthCm'], label = f'Sepal Width and Petal Width Corr = {np.round(np.corrcoef(SW,PW)[0,1], 2)}', marker='.')
plt.title('Sepal Width Correlation', fontweight='bold')
plt.xlabel('Sepal Width')
plt.legend(loc = 'best', framealpha=0.5, fontsize = 8)
plt.show()

# %%
plt.scatter(df['PetalLengthCm'], df['SepalLengthCm'], label = f'Petal Length and Sepal Length Corr = {np.round(np.corrcoef(PL,SL)[0,1], 2)}', marker='.')
plt.scatter(df['PetalLengthCm'], df['SepalWidthCm'], label = f'Petal Length and Sepal Width Corr = {np.round(np.corrcoef(PL,SW)[0,1], 2)}', marker='.')
plt.scatter(df['PetalLengthCm'], df['PetalWidthCm'], label = f'Petal Length and Petal Width Corr = {np.round(np.corrcoef(PL,PW)[0,1], 2)}', marker='.')
plt.title('Petal Length Correlation', fontweight='bold')
plt.xlabel('Petal Length')
plt.legend(loc = 'best', fontsize = 8)
plt.show()

# %%
plt.scatter(df['PetalWidthCm'], df['SepalLengthCm'], label = f'Petal Width and Sepal Length Corr = {np.round(np.corrcoef(PW,SL)[0,1], 2)}', marker='.')
plt.scatter(df['PetalWidthCm'], df['SepalWidthCm'], label = f'Petal Width and Sepal Width Corr = {np.round(np.corrcoef(PW,SW)[0,1], 2)}', marker='.')
plt.scatter(df['PetalWidthCm'], df['PetalLengthCm'], label = f'Petal Width and Petal Length Corr = {np.round(np.corrcoef(PW,PL)[0,1], 2)}', marker='.')
plt.title('Petal Width Correlation', fontweight='bold')
plt.xlabel('Petal Width')
plt.legend(loc = 'best', fontsize = 8)
plt.show()

# %% [markdown]
# Hypothesis Testing : Do setosa species have larger **sepal width** than versicolor ?

# %%
setosa = df[df['Species'] == 'Iris-setosa'][['Species', 'SepalWidthCm']]
versicolor = df[df['Species'] == 'Iris-versicolor'][['Species', 'SepalWidthCm']]
print('Iris Setosa Species Sepal Width data: ')
print(setosa)
print('\nIris Versicolor Species Sepal Width data: ')
print(versicolor)
# Out:
# Iris Setosa Species Sepal Width data:
#         Species  SepalWidthCm
# 0   Iris-setosa           3.5
# 1   Iris-setosa           3.0
# 2   Iris-setosa           3.2
# 3   Iris-setosa           3.1
# 4   Iris-setosa           3.6
# 5   Iris-setosa           3.9
# 6   Iris-setosa           3.4
# 7   Iris-setosa           3.4
# 8   Iris-setosa           2.9
# 9   Iris-setosa           3.1
# 10  Iris-setosa           3.7
# 11  Iris-setosa           3.4
# 12  Iris-setosa           3.0
# 13  Iris-setosa           3.0
# 14  Iris-setosa           4.0
# 15  Iris-setosa           4.4
# 16  Iris-setosa           3.9
# 17  Iris-setosa           3.5
# 18  Iris-setosa           3.8
# 19  Iris-setosa           3.8
# 20  Iris-setosa           3.4
# 21  Iris-setosa           3.7
# 22  Iris-setosa           3.6
# 23  Iris-setosa           3.3
# 24  Iris-setosa           3.4
# 25  Iris-setosa           3.0
# 26  Iris-setosa           3.4
# 27  Iris-setosa           3.5
# 28  Iris-setosa           3.4
# ...

# %% [markdown]
# First thing first, let's check for outliers

# %%
plt.figure(figsize=(5,3))
sns.boxplot(setosa['SepalWidthCm'])
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(5,3))
sns.boxplot(versicolor['SepalWidthCm'])
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# since we don't see any outlier in those boxplots, we can use mean / average as central tendency of the data

# %%
setosa['SepalWidthCm'].mean()
# Out:
# 3.4180000000000006

# %%
versicolor['SepalWidthCm'].mean()
# Out:
# 2.7700000000000005

# %% [markdown]
# before we go to the hypothesis test, let's check distribution of both datas with density plot

# %%
plt.figure(figsize=(5,3))
sns.distplot(setosa['SepalWidthCm'])
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(5,3))
sns.distplot(setosa['SepalWidthCm'])
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# from both density plot of setosa and versicolor species, we can see that both datas distribution is close to normal

# %% [markdown]
# Hypothesis Testing :

# %% [markdown]
# Does setosa species has larger sepal width than versicolor species ?

# %% [markdown]
# Null Hypothesis / H0 : **setosa sepal width <= versicolor sepal width**
#
# Alternative Hypothesis / H1 : **setosa sepal width > versicolor sepal width**

# %% [markdown]
# Both variables are independent, so we will perform hypothesis test with independent samples t-Test

# %%
setosa_SW = setosa['SepalWidthCm']
versicolor_SW = versicolor['SepalWidthCm']

# %%
stats, pvalue = st.ttest_ind(setosa_SW, versicolor_SW)

# %%
alpha = 0.05
print('P-Value = ', pvalue)
if pvalue >= alpha:
    print('Insufficient to reject H0')
else:
    print('Sufficient to reject H0')
# Out:
# P-Value =  4.362239016010214e-15
# Sufficient to reject H0

# %% [markdown]
# ***
# Since we failed to reject H0,
# the result of the test is : ***its proven that setosa sepal width is larger than versicolor's***
# ***

# %% [markdown]
# Thank You
